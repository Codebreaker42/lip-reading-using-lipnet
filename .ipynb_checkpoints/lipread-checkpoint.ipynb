# %%
# !pip list

# %% [markdown]
# ### Installing Dependencies and Importing them

# %%
# !pip install opencv-python matplotlib imageio gdown tensorflow

# %%
import os
import cv2
import tensorflow as tf
import numpy as np
from typing import List
from matplotlib import pyplot as plt
import imageio

# %% [markdown]
# #### To use our GPU

# %%
tf.config.list_physical_devices('GPU')
# Out:
# []

# %%
physical_devices = tf.config.list_physical_devices('GPU')
try:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
except:
    pass

# %%
# import gdown
# gdown.extractall('archive.zip')

# %%
def load_video(path:str) -> List[float]: 

    cap = cv2.VideoCapture(path)
    frames = []
    for _ in range(int(cap.get(cv2.CAP_PROP_FRAME_COUNT))): 
        ret, frame = cap.read()
        frame = tf.image.rgb_to_grayscale(frame)
        frames.append(frame[190:236,80:220,:])
    cap.release()
    
    mean = tf.math.reduce_mean(frames)
    std = tf.math.reduce_std(tf.cast(frames, tf.float32))
    # Standard normalization for a mean of zero and a standard deviation of one.
    return tf.cast((frames - mean), tf.float32) / std

# %%
vocab = [x for x in "abcdefghijklmnopqrstuvwxyz'?!123456789 "]

# %%
char_to_num = tf.keras.layers.StringLookup(vocabulary=vocab, oov_token="")
num_to_char = tf.keras.layers.StringLookup(vocabulary=char_to_num.get_vocabulary(), oov_token="", invert=True)

print(f"The vocabulary is: {char_to_num.get_vocabulary()} "f"(size ={char_to_num.vocabulary_size()})")
# Out:
# The vocabulary is: ['', np.str_('a'), np.str_('b'), np.str_('c'), np.str_('d'), np.str_('e'), np.str_('f'), np.str_('g'), np.str_('h'), np.str_('i'), np.str_('j'), np.str_('k'), np.str_('l'), np.str_('m'), np.str_('n'), np.str_('o'), np.str_('p'), np.str_('q'), np.str_('r'), np.str_('s'), np.str_('t'), np.str_('u'), np.str_('v'), np.str_('w'), np.str_('x'), np.str_('y'), np.str_('z'), np.str_("'"), np.str_('?'), np.str_('!'), np.str_('1'), np.str_('2'), np.str_('3'), np.str_('4'), np.str_('5'), np.str_('6'), np.str_('7'), np.str_('8'), np.str_('9'), np.str_(' ')] (size =40)

# %%
def load_alignments(path:str) -> List[str]: 
    with open(path, 'r') as f: 
        lines = f.readlines() 
    tokens = []
    for line in lines:
        line = line.split()
        if line[2] != 'sil': 
            tokens = [*tokens,' ',line[2]]
    return char_to_num(tf.reshape(tf.strings.unicode_split(tokens, input_encoding='UTF-8'), (-1)))[1:]

# %%
tf.version
# Out:
# <module 'tensorflow._api.v2.version' from 'n:\\major project\\lipnet\\lib\\site-packages\\tensorflow\\_api\\v2\\version\\__init__.py'>

# %%
def load_data(path: str): 
    path = bytes.decode(path.numpy())
    #file_name = path.split('/')[-1].split('.')[0]
    # File name splitting for windows
    file_name = path.split('\\')[-1].split('.')[0]
    video_path = os.path.join('data','s1',f'{file_name}.mpg')
    alignment_path = os.path.join('data','alignments','s1',f'{file_name}.align')
    frames = load_video(video_path) 
    alignments = load_alignments(alignment_path)
    
    return frames, alignments

# %%
test_path = '.\\data\\s1\\bbal6n.mpg'

# %%
frames , alignments = load_data(tf.convert_to_tensor(test_path))

# %%
frames.shape ,alignments.shape
# Out:
# (TensorShape([75, 46, 140, 1]), TensorShape([21]))

# %%
plt.imshow(frames[0])

# %%
tf.strings.reduce_join([bytes.decode(x) for x in num_to_char(alignments.numpy()).numpy()])
# Out:
# <tf.Tensor: shape=(), dtype=string, numpy=b'bin blue at l six now'>

# %%
def mappable_function(path:str) -> List[str]:
    result = tf.py_function(load_data,[path],(tf.float32,tf.int64))
    return result

# %% [markdown]
# ### Creating Data Pipeline

# %%
import os
import tensorflow as tf

# Check directory contents
print(os.listdir('data\s1'))

# Try a more flexible file matching pattern
data = tf.data.Dataset.list_files("data\s1\*")
file_list = list(data.as_numpy_iterator())
print(file_list)
# Out:
# ['bbaf2n.mpg', 'bbaf3s.mpg', 'bbaf4p.mpg', 'bbaf5a.mpg', 'bbal6n.mpg', 'bbal7s.mpg', 'bbal8p.mpg', 'bbal9a.mpg', 'bbas1s.mpg', 'bbas2p.mpg', 'bbas3a.mpg', 'bbaszn.mpg', 'bbaz4n.mpg', 'bbaz5s.mpg', 'bbaz6p.mpg', 'bbaz7a.mpg', 'bbbf6n.mpg', 'bbbf7s.mpg', 'bbbf8p.mpg', 'bbbf9a.mpg', 'bbbm1s.mpg', 'bbbm2p.mpg', 'bbbm3a.mpg', 'bbbmzn.mpg', 'bbbs4n.mpg', 'bbbs5s.mpg', 'bbbs6p.mpg', 'bbbs7a.mpg', 'bbbz8n.mpg', 'bbbz9s.mpg', 'bbie8n.mpg', 'bbie9s.mpg', 'bbif1a.mpg', 'bbifzp.mpg', 'bbil2n.mpg', 'bbil3s.mpg', 'bbil4p.mpg', 'bbil5a.mpg', 'bbir6n.mpg', 'bbir7s.mpg', 'bbir8p.mpg', 'bbir9a.mpg', 'bbiz1s.mpg', 'bbiz2p.mpg', 'bbiz3a.mpg', 'bbizzn.mpg', 'bbwg1s.mpg', 'bbwg2p.mpg', 'bbwg3a.mpg', 'bbwgzn.mpg', 'bbwm4n.mpg', 'bbwm5s.mpg', 'bbwm6p.mpg', 'bbwm7a.mpg', 'bbws8n.mpg', 'bbws9s.mpg', 'bbwt1a.mpg', 'bbwtzp.mpg', 'bgaa6n.mpg', 'bgaa7s.mpg', 'bgaa8p.mpg', 'bgaa9a.mpg', 'bgah1s.mpg', 'bgah2p.mpg', 'bgah3a.mpg', 'bgahzn.mpg', 'bgan4n.mpg', 'bgan5s.mpg', 'bgan6p.mpg', 'bgan7a.mpg', 'bgat8n.mpg', 'bgat9s.mpg', 'bgau1a.mpg', 'bgauzp.mpg', 'bgbb1s.mpg', 'bgbb2p.mpg', 'bgbb3a.mpg', 'bgbbzn.mpg', 'bgbh4n.mpg', 'bgbh5s.mpg', 'bgbh6p.mpg', 'bgbh7a.mpg', 'bgbn8n.mpg', 'bgbn9s.mpg', 'bgbo1a.mpg', 'bgbozp.mpg', 'bgbu2n.mpg', 'bgbu3s.mpg', 'bgbu4p.mpg', 'bgbu5a.mpg', 'bgia2n.mpg', 'bgia3s.mpg', 'bgia4p.mpg', 'bgia5a.mpg', 'bgig6n.mpg', 'bgig7s.mpg', 'bgig8p.mpg', 'bgig9a.mpg', 'bgin1s.mpg', 'bgin2p.mpg', 'bgin3a.mpg', 'bginzn.mpg', 'bgit4n.mpg', 'bgit5s.mpg', 'bgit6p.mpg', 'bgit7a.mpg', 'bgwb4n.mpg', 'bgwb5s.mpg', 'bgwb6p.mpg', 'bgwb7a.mpg', 'bgwh8n.mpg', 'bgwh9s.mpg', 'bgwi1a.mpg', 'bgwizp.mpg', 'bgwo2n.mpg', 'bgwo3s.mpg', 'bgwo4p.mpg', 'bgwo5a.mpg', 'bgwu6n.mpg', 'bgwu7s.mpg', 'bgwu8p.mpg', 'bgwu9a.mpg', 'braf8n.mpg', 'braf9s.mpg', 'brag1a.mpg', 'bragzp.mpg', 'bram2n.mpg', 'bram3s.mpg', 'bram4p.mpg', 'bram5a.mpg', 'bras6n.mpg', 'bras7s.mpg', 'bras8p.mpg', 'bras9a.mpg', 'brba1a.mpg', 'brbazp.mpg', 'brbg2n.mpg', 'brbg3s.mpg', 'brbg4p.mpg', 'brbg5a.mpg', 'brbm6n.mpg', 'brbm7s.mpg', 'brbm8p.mpg', 'brbm9a.mpg', 'brbt1s.mpg', 'brbt2p.mpg', 'brbt3a.mpg', 'brbtzn.mpg', 'brif4n.mpg', 'brif5s.mpg', 'brif6p.mpg', 'brif7a.mpg', 'bril8n.mpg', 'bril9s.mpg', 'brim1a.mpg', 'brimzp.mpg', 'bris2n.mpg', 'bris3s.mpg', 'bris4p.mpg', 'bris5a.mpg', 'briz6n.mpg', 'briz7s.mpg', 'briz8p.mpg', 'briz9a.mpg', 'brwa2n.mpg', 'brwa3s.mpg', 'brwa4p.mpg', 'brwa5a.mpg', 'brwg6n.mpg', 'brwg7s.mpg', 'brwg8p.mpg', 'brwg9a.mpg', 'brwn1s.mpg', 'brwn2p.mpg', 'brwn3a.mpg', 'brwnzn.mpg', 'brwt4n.mpg', 'brwt5s.mpg', 'brwt6p.mpg', 'brwt7a.mpg', 'bwaa1s.mpg', 'bwaa2p.mpg', 'bwaa3a.mpg', 'bwaazn.mpg', 'bwag4n.mpg', 'bwag5s.mpg', 'bwag6p.mpg', 'bwag7a.mpg', 'bwam8n.mpg', 'bwam9s.mpg', 'bwan1a.mpg', 'bwanzp.mpg', 'bwat2n.mpg', 'bwat3s.mpg', 'bwat4p.mpg', 'bwat5a.mpg', 'bwba4n.mpg', 'bwba5s.mpg', 'bwba6p.mpg', 'bwba7a.mpg', 'bwbg8n.mpg', 'bwbg9s.mpg', 'bwbh1a.mpg', 'bwbhzp.mpg', 'bwbn2n.mpg', 'bwbn3s.mpg', 'bwbn4p.mpg', 'bwbn5a.mpg', 'bwbt6n.mpg', 'bwbt7s.mpg', 'bwbt8p.mpg', 'bwbt9a.mpg', 'bwig1s.mpg', 'bwig2p.mpg', 'bwig3a.mpg', 'bwigzn.mpg', 'bwim4n.mpg', 'bwim5s.mpg', 'bwim6p.mpg', 'bwim7a.mpg', 'bwis8n.mpg', 'bwis9s.mpg', 'bwit1a.mpg', 'bwitzp.mpg', 'bwwa8n.mpg', 'bwwa9s.mpg', 'bwwb1a.mpg', 'bwwbzp.mpg', 'bwwh2n.mpg', 'bwwh3s.mpg', 'bwwh4p.mpg', 'bwwh5a.mpg', 'bwwn6n.mpg', 'bwwn7s.mpg', 'bwwn8p.mpg', 'bwwn9a.mpg', 'bwwu1s.mpg', 'bwwu2p.mpg', 'bwwu3a.mpg', 'bwwuzn.mpg', 'lbad6n.mpg', 'lbad7s.mpg', 'lbad8p.mpg', 'lbad9a.mpg', 'lbak1s.mpg', 'lbak2p.mpg', 'lbak3a.mpg', 'lbakzn.mpg', 'lbaq4n.mpg', 'lbaq5s.mpg', 'lbaq6p.mpg', 'lbaq7a.mpg', 'lbax8n.mpg', 'lbax9s.mpg', 'lbay1a.mpg', 'lbayzp.mpg', 'lbbe1s.mpg', 'lbbe2p.mpg', 'lbbe3a.mpg', 'lbbezn.mpg', 'lbbk4n.mpg', 'lbbk5s.mpg', 'lbbk6p.mpg', 'lbbk7a.mpg', 'lbbq8n.mpg', 'lbbq9s.mpg', 'lbbr1a.mpg', 'lbbrzp.mpg', 'lbby2n.mpg', 'lbby3s.mpg', 'lbby4p.mpg', 'lbby5a.mpg', 'lbid2n.mpg', 'lbid3s.mpg', 'lbid4p.mpg', 'lbid5a.mpg', 'lbij6n.mpg', 'lbij7s.mpg', 'lbij8p.mpg', 'lbij9a.mpg', 'lbiq1s.mpg', 'lbiq2p.mpg', 'lbiq3a.mpg', 'lbiqzn.mpg', 'lbix4n.mpg', 'lbix5s.m ...
# [b'data\\s1\\sgbc8p.mpg', b'data\\s1\\pgix8p.mpg', b'data\\s1\\pwwq8n.mpg', b'data\\s1\\sgbv8n.mpg', b'data\\s1\\sbwu6p.mpg', b'data\\s1\\pbai7a.mpg', b'data\\s1\\sriu1a.mpg', b'data\\s1\\bwbt9a.mpg', b'data\\s1\\prwx7s.mpg', b'data\\s1\\brbg5a.mpg', b'data\\s1\\lwar7s.mpg', b'data\\s1\\pbap1a.mpg', b'data\\s1\\lriezp.mpg', b'data\\s1\\pgbr2p.mpg', b'data\\s1\\lrbl2p.mpg', b'data\\s1\\pbac3a.mpg', b'data\\s1\\bgan4n.mpg', b'data\\s1\\swwv8p.mpg', b'data\\s1\\brbt1s.mpg', b'data\\s1\\pgby7a.mpg', b'data\\s1\\sria8p.mpg', b'data\\s1\\bbbm1s.mpg', b'data\\s1\\lgil7a.mpg', b'data\\s1\\pgay1s.mpg', b'data\\s1\\pbbp5a.mpg', b'data\\s1\\sbit5a.mpg', b'data\\s1\\sbahzp.mpg', b'data\\s1\\swwi8n.mpg', b'data\\s1\\lwbf2n.mpg', b'data\\s1\\lgir9s.mpg', b'data\\s1\\pgix7s.mpg', b'data\\s1\\sraozp.mpg', b'data\\s1\\pgwz1a.mpg', b'data\\s1\\lgiz3s.mpg', b'data\\s1\\swih8p.mpg', b'data\\s1\\sbwu4n.mpg', b'data\\s1\\bram5a.mpg', b'data\\s1\\prajzn.mpg', b'data\\s1\\prwx8p.mpg', b'data\\s1\\lwws5s.mpg', b'data\\s1\\sgbxzp.mpg', b'data\\s1\\pgaezp.mpg', b'data\\s1\\sgbj1s.mpg', b'data\\s1\\prbd3a.mpg', b'data\\s1\\lbwy8p.mpg', b'data\\s1\\pwip6n.mpg', b'data\\s1\\sgivzn.mpg', b'data\\s1\\bwis9s.mpg', b'data\\s1\\pbib6n.mpg', b'data\\s1\\lwal5a.mpg', b'data\\s1\\pgwl1s.mpg', b'data\\s1\\lrak9a.mpg', b'data\\s1\\lwil1a.mpg', b'data\\s1\\pgwr5s.mpg', b'data\\s1\\srwv1s.mpg', b'data\\s1\\bwbt6n.mpg', b'data\\s1\\pwwr1a.mpg', b'data\\s1\\lrblzn.mpg', b'data\\s1\\pbac2p.mpg', b'data\\s1\\lrwl5s.mpg', b'data\\s1\\pbbc4n.mpg', b'data\\s1\\bgahzn.mpg', b'data\\s1\\sgbc6n.mpg', b'data\\s1\\lgwm9a.mpg', b'data\\s1\\pbiu9s.mpg', b'data\\s1\\pgwe7s.mpg', b'data\\s1\\lgwm7s.mpg', b'data\\s1\\sbat6n.mpg', b'data\\s1\\bgwb5s.mpg', b'data\\s1\\bgwb6p.mpg', b'data\\s1\\bwbh1a.mpg', b'data\\s1\\bram2n.mpg', b'data\\s1\\sgbp5s.mpg', b'data\\s1\\bbwm6p.mpg', b'data\\s1\\lgbf9s.mpg', b'data\\s1\\srbb4n.mpg', b'data\\s1\\sbwo2p.mpg', b'data\\s1\\pbii1s.mpg', b'data\\s1\\sbbu3a.mpg', b'data\\s1\\lbby3s.mpg', b'data\\s1\\lbad7s.mpg', b'data\\s1\\prbq1a.mpg', b'data\\s1\\pripzn.mpg', b'data\\s1\\bbil4p.mpg', b'data\\s1\\pwaq3a.mpg', b'data\\s1\\pgwr6p.mpg', b'data\\s1\\bwwuzn.mpg', b'data\\s1\\swao4n.mpg', b'data\\s1\\brwg7s.mpg', b'data\\s1\\praj1s.mpg', b'data\\s1\\lgal9s.mpg', b'data\\s1\\brwt4n.mpg', b'data\\s1\\brwa3s.mpg', b'data\\s1\\pgay2p.mpg', b'data\\s1\\pgid5s.mpg', b'data\\s1\\sgap2p.mpg', b'data\\s1\\sgbjzn.mpg', b'data\\s1\\bgbh4n.mpg', b'data\\s1\\sria6n.mpg', b'data\\s1\\pbio7a.mpg', b'data\\s1\\bgwo5a.mpg', b'data\\s1\\bwwn7s.mpg', b'data\\s1\\pwix1s.mpg', b'data\\s1\\pgaq8p.mpg', b'data\\s1\\pwwy4p.mpg', b'data\\s1\\lgaz9a.mpg', b'data\\s1\\pwbq4n.mpg', b'data\\s1\\pwix2p.mpg', b'data\\s1\\prbx5a.mpg', b'data\\s1\\lrby8n.mpg', b'data\\s1\\bgig6n.mpg', b'data\\s1\\lwbf5a.mpg', b'data\\s1\\swab7s.mpg', b'data\\s1\\lbwe5s.mpg', b'data\\s1\\lriq6n.mpg', b'data\\s1\\srihzn.mpg', b'data\\s1\\pgiq2n.mpg', b'data\\s1\\sgap3a.mpg', b'data\\s1\\bwat5a.mpg', b'data\\s1\\lbbq9s.mpg', b'data\\s1\\bgig7s.mpg', b'data\\s1\\sbbn8p.mpg', b'data\\s1\\pwby1a.mpg', b'data\\s1\\lgbg1a.mpg', b'data\\s1\\swavzp.mpg', b'data\\s1\\bgah3a.mpg', b'data\\s1\\sgwx2n.mpg', b'data\\s1\\swau8n.mpg', b'data\\s1\\pbbp4p.mpg', b'data\\s1\\pwwy3s.mpg', b'data\\s1\\swbv5a.mpg', b'data\\s1\\brif7a.mpg', b'data\\s1\\lriy3a.mpg', b'data\\s1\\swao6p.mpg', b'data\\s1\\lgbs8p.mpg', b'data\\s1\\swai3a.mpg', b'data\\s1\\pgak5a.mpg', b'data\\s1\\swwjzp.mpg', b'data\\s1\\bbbf7s.mpg', b'data\\s1\\bbwm5s.mpg', b'data\\s1\\bwag7a.mpg', b'data\\s1\\pwwy5a.mpg', b'data\\s1\\lbid3s.mpg', b'data\\s1\\sban3s.mpg', b'data\\s1\\pbio4n.mpg', b'data\\s1\\prbd2p.mpg', b'data\\s1\\sgib9s.mpg', b'data\\s1\\swbc2p.mpg', b'data\\s1\\lwir2n.mpg', b'data\\s1\\pbapzp.mpg', b'data\\s1\\pgix6n.mpg', b'data\\s1\\pgwl2p.mpg', b'data\\s1\\bbws9s.mpg', b'data\\s1\\lbwr3s.mpg', b'data\\s1\\swih7s.mpg', b'data\\s1\\pgwe6n.mpg', b'data\\s1\\lgbm4p.mpg', b'data\\s1\\pgad9s.mpg', b'data\\s1\\srwv3a.mpg', b'data\\s1\\brwa5a.mpg', ...

# %%
data = tf.data.Dataset.list_files("data\s1\*.mpg")
data = data.shuffle(500, reshuffle_each_iteration = False)
data = data.map(mappable_function)
data = data.padded_batch(2, padded_shapes=([75,None,None,None],[40]))    # lenght of each alignmets is going to be diffrent so we have padded it to make its lengh same for all 
data = data.prefetch(tf.data.AUTOTUNE)    # prefetchs data batches asynchronously during model training

train = data.take(450)
test = data.skip(450)

# %%
len(test)
# Out:
# 50

# %%
frames, alignments = data.as_numpy_iterator().next()

# %%
len(frames)   ## now we have 2 videos in each batch
# Out:
# 2

# %%
testx = data.as_numpy_iterator()

# %%
val = testx.next(); val[0]
# Out:
# array([[[[[ 1.0894324 ],
#           [ 1.014299  ],
#           [ 1.2021322 ],
#           ...,
#           [ 0.30053306],
#           [ 0.22539979],
#           [ 0.22539979]],
#
#          [[ 1.3899654 ],
#           [ 1.2021322 ],
#           [ 1.2772655 ],
#           ...,
#           [ 0.30053306],
#           [ 0.22539979],
#           [ 0.22539979]],
#
#          [[ 1.7280651 ],
#           [ 1.3148321 ],
#           [ 1.0518657 ],
#           ...,
#           [ 0.30053306],
#           [ 0.22539979],
#           [ 0.22539979]],
#
#          ...,
#
#          [[ 0.97673243],
#           [ 0.97673243],
#           [ 0.97673243],
#           ...,
#           [ 0.        ],
#           [ 0.        ],
#           [ 0.        ]],
#
#          [[ 0.93916583],
#           [ 0.93916583],
#           [ 0.93916583],
#           ...,
#           [ 9.579492  ],
#           [ 9.579492  ],
#           [ 9.579492  ]],
#
#          [[ 0.93916583],
#           [ 0.93916583],
#           [ 0.93916583],
#           ...,
#           [ 9.579492  ],
#           [ 9.579492  ],
#           [ 9.579492  ]]],
#
#
#         [[[ 1.1645656 ],
#           [ 1.0894324 ],
#           [ 1.3148321 ],
#           ...,
#           [ 0.22539979],
#           [ 0.18783316],
#           [ 0.18783316]],
#
#          [[ 1.2772655 ],
#           [ 1.126999  ],
#           [ 1.0894324 ],
#           ...,
#           [ 0.22539979],
#           [ 0.18783316],
#           [ 0.18783316]],
#
#          [[ 1.7656317 ],
#           [ 1.3899654 ],
#           [ 0.90159917],
#           ...,
#           [ 0.22539979],
#           [ 0.22539979],
#           [ 0.18783316]],
#
#          ...,
#
#          [[ 0.97673243],
#           [ 0.97673243],
#           [ 0.97673243],
#           ...,
#           [ 0.        ],
#           [ 0.        ],
#           [ 0.        ]],
#
#          [[ 0.97673243],
#           [ 0.97673243],
#           [ 0.97673243],
#           ...,
#           [ 9.579492  ],
#           [ 9.579492  ],
#           [ 9.579492  ]],
#
#          [[ 0.93916583],
#           [ 0.93916583],
#           [ 0.93916583],
#           ...,
#           [ 9.579492  ],
#           [ 9.579492  ],
#           [ 9.579492  ]]],
#
#
#         [[[ 1.014299  ],
#           [ 1.0894324 ],
#           [ 1.3148321 ],
#           ...,
#           [ 0.22539979],
#           [ 0.18783316],
#           [ 0.18783316]],
#
#          [[ 1.1645656 ],
#           [ 1.0518657 ],
#           [ 1.0518657 ],
#           ...,
#           [ 0.22539979],
#           [ 0.18783316],
#           [ 0.18783316]],
#
#          [[ 1.6529318 ],
#           [ 1.3523988 ],
#           [ 0.86403257],
#           ...,
#           [ 0.22539979],
#           [ 0.22539979],
#           [ 0.18783316]],
#
#          ...,
#
#          [[ 1.014299  ],
#           [ 1.014299  ],
#           [ 1.014299  ],
#           ...,
#           [ 0.03756663],
#           [ 0.        ],
#           [ 0.        ]],
#
#          [[ 0.97673243],
#           [ 0.97673243],
#           [ 0.97673243],
#           ...,
#           [ 0.        ],
#           [ 9.579492  ],
#           [ 9.579492  ]],
#
#          [[ 0.93916583],
#           [ 0.93916583],
#           [ 0.93916583],
#           ...,
#           [ 0.        ],
#           [ 9.579492  ],
#           [ 9.579492  ]]],
#
#
#         ...,
#
#
#         [[[ 1.0894324 ],
#           [ 1.6529318 ],
#           [ 1.3899654 ],
#           ...,
#           [ 0.15026653],
#           [ 0.15026653],
#           [ 0.15026653]],
#
#          [[ 0.48836622],
#           [ 1.3899654 ],
#           [ 1.3899654 ],
#           ...,
#           [ 0.15026653],
#           [ 0.15026653],
#           [ 0.15026653]],
#
#          [[ 0.48836622],
#           [ 1.014299  ],
#           [ 1.1645656 ],
#           ...,
#           [ 0.15026653],
#           [ 0.15026653],
#           [ 0.15026653]],
#
#          ...,
#
#          [[ 0.97673243],
#           [ 0.93916583],
#           [ 0.93916583],
#           ...,
#           [ 0.        ],
#           [ 0.        ],
#           [ 0.        ]],
#
#          [[ 0.93916583],
#           [ 0.93916583],
#           [ 0.93916583],
#           ...,
#           [ 0.        ],
#           [ 0.        ],
#           [ 9.579492  ]],
#
#          [[ 0.93916583],
#           [ 0.93916583],
#           [ 0.93916583],
#           ...,
#           [ 0.        ],
#           [ 9.579492  ],
#           [ 9.579492  ]]],
#
#
#         [[[ 1.126999  ],
#           [ 1.6153651 ],
#           [ 1.2772655 ],
#           ...,
#           [ 0.18783316],
#           [ 0.15026653],
#           [ 0.15026653]],
#
#          [[ 0.37566632],
#           [ 1.2772655 ],
#           [ 1.3523988 ],
#           ...,
#           [ 0.18783316],
#           [ 0.15026653],
#           [ 0.15026653]],
#
#          [[ 0.52593285],
#           [ 1.0894324 ],
#           [ 1.2396989 ],
#           ...,
#           [ 0.15026653],
#           [ 0.15026653],
#           [ 0.15026653]],
#
#          ...,
#
#          [[ 0.97673243],
#           [ 0.97673243],
#           [ 0.93916583],
#           ...,
#           [ 0.        ],
#           [ 9.579492  ],
#           [ 9.579492  ]],
#
#          [[ 0.97673243],
#           [ 0.93916583],
#           [ 0.93916583],
#           ...,
#           [ 0.        ],
#           [ 9.579492  ],
#           [ 9.541924  ]],
#
#          [[ 0.97673243],
#           [ 0.93916583],
#           [ 0.93916583],
#           ...,
#           [ 0.        ],
#           [ 9.541924  ],
#           [ 9.541924  ]]],
#
#
#         [[[ 1.2772655 ],
#           [ 1.7280651 ],
#           [ 1.2396989 ],
#           ...,
#           [ 0.18783316],
#           [ 0.15026653],
#           [ 0.15026653]],
#
#          [[ 0.3380997 ],
#           [ 1.4650986 ],
#           [ 1.4275321 ],
#           ...,
#           [ 0.18783316],
#           [ 0.15026653],
#           [ 0.15026653]],
#
#          [[ 0.6010661 ],
#           [ 1.5026653 ],
#           [ 1.5026653 ],
#           ...,
#           [ 0.15026653],
#           [ 0.15026653],
#           [ 0.15026653]],
#
#          ...,
#
#          [[ 1.014299  ],
#           [ 1.014299  ],
#           [ 0.97673243],
#           ...,
#           [ 9.579492  ],
#           [ 9.579492  ],
#           [ 9.579492  ]],
#
#          [[ 1.014299  ],
#           [ 1.014299  ],
#           [ 0.97673243],
#           ...,
#           [ 9.579492  ],
#           [ 9.579492  ],
#           [ 9.541924  ]],
#
#          [[ 1.014299  ],
#           [ 1.014299  ],
#           [ 0.97673243],
#           ...,
#           [ 9.579492  ],
#           [ 9.541924  ],
#           [ 9.541924  ]]]],
#
#
#
#        [[[[ 1.1830435 ],
#           [ 1.1041739 ],
#           [ 0.74926084],
#           ...,
#           [ 0.31547827],
#           [ 0.27604347],
#           [ 0.27604347]],
#
#          [[ 1.0253043 ],
#           [ 1.0647391 ],
#           [ 0.63095653],
#           ...,
#           [ 0.31547827],
#           [ 0.27604347],
#           [ 0.27604347]],
#
#          [[ 1.3013479 ],
#           [ 1.3013479 ],
#           [ 1.0253043 ],
#           ...,
#           [ 0.27604347],
#           [ 0.19717391],
#           [ 0.19717391]],
#
#          ...,
#
#          [[ 1.1436087 ],
#           [ 1.0647391 ],
#           [ 1.1041739 ],
#           ...,
#           [ 0.        ],
#           [10.05587   ],
#           [10.05587   ]],
#
#          [[ 1.0647391 ],
#           [ 1.0647391 ],
#           [ 1.1041739 ],
#           ...,
#           [ 0.        ],
#           [10.05587   ],
#           [10.05587   ]],
#
#          [[ 1.0647391 ],
#           [ 1.0647391 ],
#           [ 1.1041739 ],
#           ...,
#           [ 0.        ],
#           [10.05587   ],
#           [10.05587   ]]],
#
#
#         [[[ 1.2224783 ],
#           [ 1.2224783 ],
#           [ 0.63095653],
#           ...,
#           [ 0.15773913],
#           [ 0.15773913],
#           [ 0.15773913]],
#
#          [[ 1.0253043 ],
#           [ 1.2224783 ],
#           [ 0.63095653],
#           ...,
#           [ 0.15773913],
#           [ 0.15773913],
#           [ 0.15773913]],
#
#          [[ 1.459087  ],
#           [ 1.3802174 ],
#           [ 1.0647391 ],
#           ...,
#           [ 0.19717391],
#           [ 0.15773913],
#           [ 0.15773913]],
#
#          ...,
#
#          [[ 1.1041739 ],
#           [ 1.1041739 ],
#           [ 1.0647391 ],
#           ...,
#           [ 0.03943478],
#           [ 0.        ],
#           [ 0.        ]],
#
#          [[ 1.1041739 ],
#           [ 1.1041739 ],
#           [ 1.1041739 ],
#           ...,
#           [ 0.03943478],
#           [ 0.        ],
#           [ 0.        ]],
#
#          [[ 1.0647391 ],
#           [ 1.0647391 ],
#           [ 1.0253043 ],
#           ...,
#           [ 0.        ],
#           [10.05587   ],
#           [10.05587   ]]],
#
#
#         [[[ 1.3013479 ],
#           [ 1.2619131 ],
#           [ 0.59152174],
#           ...,
#           [ 0.19717391],
#           [ 0.19717391],
#           [ 0.19717391]],
#
#          [[ 1.1830435 ],
#           [ 1.1830435 ],
#           [ 0.6703913 ],
#           ...,
#           [ 0.19717391],
#           [ 0.19717391],
#           [ 0.19717391]],
#
#          [[ 1.459087  ],
#           [ 1.4196522 ],
#           [ 1.0647391 ],
#           ...,
#           [ 0.19717391],
#           [ 0.15773913],
#           [ 0.15773913]],
#
#          ...,
#
#          [[ 1.1041739 ],
#           [ 1.1041739 ],
#           [ 1.0647391 ],
#           ...,
#           [ 0.        ],
#           [10.05587   ],
#           [10.05587   ]],
#
#          [[ 1.1041739 ],
#           [ 1.1041739 ],
#           [ 1.0647391 ],
#           ...,
#           [ 0.        ],
#           [10.05587   ],
#           [10.05587   ]],
#
#          [[ 1.0647391 ],
#           [ 1.0647391 ],
#           [ 1.0253043 ],
#           ...,
#           [10.05587   ],
#           [10.016435  ],
#           [10.016435  ]]],
#
#
#         ...,
#
#
#         [[[ 1.1041739 ],
#           [ 0.9858696 ],
#           [ 0.59152174],
#           ...,
#           [ 0.19717391],
#           [ 0.19717391],
#           [ 0.19717391]],
#
#          [[ 1.1041739 ],
#           [ 0.9858696 ],
#           [ 0.35491306],
#           ...,
#           [ 0.15773913],
#           [ 0.15773913],
#           [ 0.15773913]],
#
#          [[ 1.2619131 ],
#           [ 1.3013479 ],
#           [ 1.1436087 ],
#           ...,
#           [ 0.15773913],
#           [ 0.15773913],
#           [ 0.15773913]],
#
#          ...,
#
#          [[ 1.0253043 ],
#           [ 1.0253043 ],
#           [ 0.9858696 ],
#           ...,
#           [10.05587   ],
#           [10.05587   ],
#           [10.05587   ]],
#
#          [[ 1.0253043 ],
#           [ 1.0253043 ],
#           [ 0.9858696 ],
#           ...,
#           [10.05587   ],
#           [10.05587   ],
#           [10.016435  ]],
#
#          [[ 1.0253043 ],
#           [ 1.0253043 ],
#           [ 0.9858696 ],
#           ...,
#           [10.05587   ],
#           [10.016435  ],
#           [10.016435  ]]],
#
#
#         [[[ 1.2619131 ],
#           [ 1.0647391 ],
#           [ 0.7098261 ],
#           ...,
#           [ 0.2366087 ],
#           [ 0.15773913],
#           [ 0.15773913]],
#
#          [[ 1.1436087 ],
#           [ 1.1041739 ],
#           [ 0.39434782],
#           ...,
#           [ 0.15773913],
#           [ 0.11830435],
#           [ 0.11830435]],
#
#          [[ 1.2224783 ],
#           [ 1.2619131 ],
#           [ 0.9858696 ],
#           ...,
#           [ 0.15773913],
#           [ 0.15773913],
#           [ 0.15773913]],
#
#          ...,
#
#          [[ 1.1041739 ],
#           [ 1.0647391 ],
#           [ 1.0647391 ],
#           ...,
#           [10.05587   ],
#           [10.05587   ],
#           [10.05587   ]],
#
#          [[ 1.0647391 ],
#           [ 1.0253043 ],
#           [ 0.9858696 ],
#           ...,
#           [10.05587   ],
#           [10.05587   ],
#           [10.05587   ]],
#
#          [[ 1.0647391 ],
#           [ 1.0253043 ],
#           [ 0.9858696 ],
#           ...,
#           [10.05587   ],
#           [10.05587   ],
#           [10.016435  ]]],
#
#
#         [[[ 1.1830435 ],
#           [ 1.0647391 ],
#           [ 0.78869563],
#           ...,
#           [ 0.15773913],
#           [ 0.15773913],
#           [ 0.15773913]],
#
#          [[ 1.1041739 ],
#           [ 1.0647391 ],
#           [ 0.4337826 ],
#           ...,
#           [ 0.15773913],
#           [ 0.15773913],
#           [ 0.15773913]],
#
#          [[ 1.3407826 ],
#           [ 1.3802174 ],
#           [ 1.1041739 ],
#           ...,
#           [ 0.15773913],
#           [ 0.15773913],
#           [ 0.15773913]],
#
#          ...,
#
#          [[ 1.0253043 ],
#           [ 1.0253043 ],
#           [ 1.0647391 ],
#           ...,
#           [10.05587   ],
#           [10.05587   ],
#           [10.05587   ]],
#
#          [[ 1.0647391 ],
#           [ 1.0647391 ],
#           [ 0.9858696 ],
#           ...,
#           [10.05587   ],
#           [10.05587   ],
#           [10.05587   ]],
#
#          [[ 1.0647391 ],
#           [ 1.0647391 ],
#           [ 0.9858696 ],
#           ...,
#           [10.05587   ],
#           [10.05587   ],
#           [10.016435  ]]]]], dtype=float32)

# %%
# 0:videos, 0: 1st video out of the batch,  0: return the first frame in the video 
plt.imshow(val[0][0][24])

# %%
directory = 'animations'

if not os.path.exists(directory):
    os.makedirs(directory)
    print(f"Directory '{directory}' created successfully.")
else:
    print(f"Directory '{directory}' already exists.")
# Out:
# Directory 'animations' already exists.

# %%
# Create the animations directory if it doesn't exist
output_directory = ".\\animations"
os.makedirs(output_directory, exist_ok=True)

output_path = os.path.join(output_directory, "animation.gif")

# Rest of your code remains the same
video_frames = val[0][1]
video_frames = np.squeeze(video_frames)

num_frames, height, width = video_frames.shape
video_frames_uint8 = (video_frames * 255).astype(np.uint8)
video_frames_reshaped = np.reshape(video_frames_uint8, (num_frames, height, width))

imageio.mimsave(output_path, video_frames_reshaped, fps=10)

print(f"Animation saved successfully to: {output_path}")
# Out:
# Animation saved successfully to: .\animations\animation.gif

# %%
from IPython.display import Image

# Specify the path to the saved GIF
gif_path = '.\\animations\\animation.gif'

# Display the GIF
Image(filename=gif_path, width=400, height=300 , )

# %%
tf.strings.reduce_join([num_to_char(word) for word in val[1][0]])
# Out:
# <tf.Tensor: shape=(), dtype=string, numpy=b'bin red with n two please'>

# %% [markdown]
# ### Designing the Deep Neural Netwok

# %%
# pip install --upgrade tensorflow

# %%
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Conv3D, LSTM, Dense, Dropout, Bidirectional, MaxPool3D, Activation, Reshape, SpatialDropout3D, BatchNormalization, TimeDistributed, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler

# %%
data.as_numpy_iterator().next()[0][0].shape
# Out:
# (75, 46, 140, 1)

# %%
model = Sequential()
model.add(Conv3D(128, (3, 3, 3), input_shape=(75, 40, 140, 1), padding='same'))
model.add(Activation('relu'))
model.add(MaxPool3D((1, 2, 2)))

model.add(Conv3D(256, (3, 3, 3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPool3D((1, 2, 2)))

model.add(Conv3D(75, (3, 3, 3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPool3D((1, 2, 2)))


# model.add(TimeDistributed(Flatten()))
model.add(Reshape(( 75, -1)))

model.add(Bidirectional(LSTM(128, return_sequences=True)))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(128, return_sequences=True)))
model.add(Dropout(0.5))

model.add(Dense(char_to_num.vocabulary_size()+1, kernel_initializer="he_normal", activation="softmax"))

# model.add(Dense(char_to_num.vocabulary_size() + 1, kernel_initializer="he_normal", activation="softmax"))
# Out:
# n:\major project\lipnet\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv3d (Conv3D)                 │ (None, 75, 40, 140,    │         3,584 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 75, 40, 140,    │             0 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d (MaxPooling3D)    │ (None, 75, 20, 70,     │             0 │
# │                                 │ 128)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_1 (Conv3D)               │ (None, 75, 20, 70,     │       884,992 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 75, 20, 70,     │             0 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_1 (MaxPooling3D)  │ (None, 75, 10, 35,     │             0 │
# │                                 │ 256)                   │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_2 (Conv3D)               │ (None, 75, 10, 35, 75) │       518,475 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 75, 10, 35, 75) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_2 (MaxPooling3D)  │ (None, 75, 5, 17, 75)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 75, 6375)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 75, 256)        │     6,660,096 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 75, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 75, 256)        │       394,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 75, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 75, 41)         │        10,537 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,471,924 (32.32 MB)
#  Trainable params: 8,471,924 (32.32 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Model architecture from the LipNet paper
# ![image.png](attachment:73b4aa47-4f5b-4745-b51a-142969f05b29.png)
# I have used BidirectionalLSTM instead of Bi-GRU

# %%
yhat = model.predict(val[0])
tf.strings.reduce_join([num_to_char(tf.argmax(x)) for x in yhat[1]])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# <tf.Tensor: shape=(), dtype=string, numpy=b'hnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn'>

# %%
model.input_shape, model.output_shape
# Out:
# ((None, 75, 40, 140, 1), (None, 75, 41))

# %% [markdown]
# ### Seting up Traing options and Train the Model

# %%
def scheduler(epoch, lr):
    if epoch < 30:
        return lr
    else:
        return lr * tf.math.exp(-0.1)

# %%
def CTC_loss(y_true, y_pred): #https://keras.io/examples/audio/ctc_asr/
    batch_len = tf.cast(tf.shape(y_true)[0], dtype="int64")
    input_length = tf.cast(tf.shape(y_pred)[1], dtype="int64")
    label_length = tf.cast(tf.shape(y_true)[1], dtype="int64")
    
    input_length = input_length * tf.ones(shape=(batch_len,1), dtype="int64")
    label_length = label_length * tf.ones(shape=(batch_len,1), dtype="int64")
    
    loss = tf.keras.backend.ctc_batch_cost(y_true, y_pred, input_length, label_length)
    return loss

# %%
class produce_example(tf.keras.callbacks.Callback):
    def __init__(self, dataset) -> None: 
        self.dataset = dataset.as_numpy_iterator()
    
    def on_epoch_end(self, epoch, logs=None) -> None:
        data = self.dataset.next()
        yhat = self.model.predict(data[0])
        decoded = tf.keras.backend.ctc_decode(yhat, [75,75], greedy=False)[0][0].numpy()
        for x in range(len(yhat)):           
            print('Original:', tf.strings.reduce_join(num_to_char(data[1][x])).numpy().decode('utf-8'))
            print('Prediction:', tf.strings.reduce_join(num_to_char(decoded[x])).numpy().decode('utf-8'))




# class ProduceExampleCallback(tf.keras.callbacks.Callback):
#     def __init__(self, dataset):
#         super(ProduceExampleCallback, self).__init__()
#         self.dataset = dataset  # Assuming `dataset` is a TensorFlow dataset object

#     def on_epoch_end(self, epoch, logs=None):
#         # Get a batch of data from the dataset
#         data = next(iter(self.dataset.batch(1)))

#         inputs, targets = data[0], data[1]

#         # Make predictions using the model
#         predictions = self.model.predict(inputs)

#         # Decode predictions and targets to text
#         decoded_targets = tf.strings.reduce_join([vocab[word] + " " for word in targets[0]]).numpy().decode('utf-8')
#         decoded_predictions = tf.strings.reduce_join([vocab[word] + " " for word in predictions[0]]).numpy().decode('utf-8')

#         # Print original and predicted text
#         print(f"Original: {decoded_targets}")
#         print(f"Prediction: {decoded_predictions}")
#         print("-" * 50)

# %%
# from tensorflow.keras.optimizers.legacy import Adam

# %%
model.compile(optimizer=Adam(learning_rate=0.0001), loss=CTC_loss)

# %%
# !mkdir models
# Out:
# A subdirectory or file models already exists.

# %%
checkpoint_callback = ModelCheckpoint(os.path.join('models','checkpoint.weights.h5'), monitor='loss', save_weights_only=True)

# %%
schedule_callback = LearningRateScheduler(scheduler)

# %%
example_callback = produce_example(test)

# %%
model.load_weights('models/checkpoint.weights.h5')
# Out:
# n:\major project\lipnet\lib\site-packages\keras\src\saving\saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 42 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %% [markdown]
# ### Testing the model

# %%
# test_data = test.as_numpy_iterator()
# sample = test_data.next()

# %%
# yhat = model.predict(sample[0])

# %%
# print('~'*100, 'REAL TEXT')
# [tf.strings.reduce_join([num_to_char(word) for word in sentence]) for sentence in sample[1]]

# %%
# decoded = tf.keras.backend.ctc_decode(yhat, input_length=[75,75], greedy=True)[0][0].numpy()

# %%
# print('~'*100, 'PREDICTIONS')
# [tf.strings.reduce_join([num_to_char(word) for word in sentence]) for sentence in decoded]

# %% [markdown]
# #### testing on a video

# %%
sample = load_data(tf.convert_to_tensor('.\\test\\brwg8p.mpg'))

# %%
print('~'*100, 'REAL TEXT')
[tf.strings.reduce_join([num_to_char(word) for word in sentence]) for sentence in [sample[1]]]
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ REAL TEXT
# [<tf.Tensor: shape=(), dtype=string, numpy=b'bin red with g eight please'>]

# %%
yhat = model.predict(tf.expand_dims(sample[0], axis=0))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %%
decoded = tf.keras.backend.ctc_decode(yhat, input_length=[75], greedy=True)[0][0].numpy()

# %%
print('~'*100, 'PREDICTIONS')
[tf.strings.reduce_join([num_to_char(word) for word in sentence]) for sentence in decoded]
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ PREDICTIONS
# [<tf.Tensor: shape=(), dtype=string, numpy=b' bin red with g eight please'>]
